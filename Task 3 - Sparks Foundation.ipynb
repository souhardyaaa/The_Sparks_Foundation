# %% [markdown]
# # NAME : SOUHARDYA CHATTOPADHYAY
#
#
# ## TASK  : To explore Unsupervised Machine Learning
#
#
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets
from sklearn.cluster import KMeans
# %matplotlib inline
sns.set()

# %% [markdown]
# ### Import Data

# %%
iris = datasets.load_iris()
iris_data = pd.DataFrame(iris.data, columns = iris.feature_names)

# %% [markdown]
# ### View the Top 5 rows of the Data

# %%
iris_data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %% [markdown]
# ### Summary of the Data

# %%
iris_data.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %% [markdown]
# ### Visualize the relationship between Features

# %%
plt.scatter(x = 'sepal length (cm)', y = 'sepal width (cm)', data = iris_data)
plt.xlabel('sepal length (cm)', fontsize=15)
plt.ylabel('sepal width (cm)', fontsize=15)
plt.show()

# %% [markdown]
# ### Finding K using elbow Method

# %%
plt.scatter(x = 'petal length (cm)', y = 'petal width (cm)', data = iris_data, color='y')
plt.xlabel('petal length (cm)', fontsize=15)
plt.ylabel('petal width (cm)', fontsize=15)
plt.show()

# %%
wcss=[]
k_range=10
for i in range(1,k_range):
    k=KMeans(i)
    k.fit(iris_data)
    w=k.inertia_
    wcss.append(w)
wcss
# Out:
# [681.3705999999996,
#  152.34795176035797,
#  78.851441426146,
#  57.22847321428572,
#  46.47223015873018,
#  39.03998724608725,
#  34.40900974025975,
#  30.014398496240617,
#  27.983703661327244]

# %%
clusters=range(1,k_range)
plt.plot(clusters,wcss,  marker='.', color = "g", markersize=10)
plt.xlabel('No of clusters', fontsize=15)
plt.ylabel('WCSS', fontsize=15)
plt.title('The elbow method', fontsize=25)
plt.show()

# %% [markdown]
# ### K = 2 Clusters

# %%
kmeans_2=KMeans(2)
kmeans_2.fit(iris_data)
# Out:
# KMeans(n_clusters=2)

# %% [markdown]
# ### Visualizing clusters according to predicted value

# %%
iris_pred_2=iris_data.copy()
iris_pred_2['predicted']=kmeans_2.fit_predict(iris_data)

# %%
plt.scatter(x='sepal length (cm)', y='sepal width (cm)', c='predicted', cmap = 'RdYlGn', data=iris_pred_2)
plt.xlabel('sepal length', fontsize=15)
plt.ylabel('sepal width', fontsize=15)
plt.title('K=2 Sepal length vs sepal width', fontsize=20)
plt.show()

# %%
plt.scatter(x='petal length (cm)', y='petal width (cm)', c='predicted', cmap = 'jet', data=iris_pred_2)
plt.xlabel('petal length', fontsize=15)
plt.ylabel('petal width', fontsize=15)
plt.title('K=2 petal length vs petal width', fontsize=20)
plt.show()

# %% [markdown]
# ### K = 2 Clusters

# %%
kmeans_3=KMeans(3)
kmeans_3.fit(iris_data)
# Out:
# KMeans(n_clusters=3)

# %% [markdown]
# ### Visualizing clusters according to predicted value

# %%
iris_pred_3=iris_data.copy()
iris_pred_3['predicted']=kmeans_3.fit_predict(iris_data)

# %%
plt.scatter(x='sepal length (cm)', y='sepal width (cm)', c='predicted', cmap = 'gist_rainbow', data=iris_pred_3)
plt.xlabel('sepal length', fontsize=15)
plt.ylabel('sepal width', fontsize=15)
plt.title('K=3 Sepal length vs sepal width', fontsize=20)
plt.show()

# %%
plt.scatter(x='petal length (cm)', y='petal width (cm)', c='predicted', cmap = 'gnuplot2_r', data=iris_pred_3)
plt.xlabel('petal length', fontsize=15)
plt.ylabel('petal width', fontsize=15)
plt.title('K=3 petal length vs petal width', fontsize=20)
plt.show()

# %% [markdown]
# ### Visualizing clusters for true label values

# %%
plt.scatter(x='sepal length (cm)', y='sepal width (cm)', c=iris.target, cmap = 'rainbow', data=iris_data)
plt.xlabel('sepal length', fontsize=15)
plt.ylabel('sepal width', fontsize=15)
plt.title('Sepal length vs sepal width', fontsize=20)
plt.show()

# %%
plt.scatter(x='petal length (cm)', y='petal width (cm)', c=iris.target, cmap = 'jet', data=iris_data)
plt.xlabel('petal length', fontsize=15)
plt.ylabel('petal width', fontsize=15)
plt.title('petal length vs petal width', fontsize=20)
plt.show()

# %% [markdown]
# After visualizing the clusters for true labels,we can say K=3 is more appropriate solution for iris dataset. Examining the scatter plots (petal length vs petal width) and (sepal length vs sepal width), we observe the features that differentiate the species better are petals features and not sepals feature.
#
# Conclusion : KMeans is better suited for problems where the number of clusters are already known.
